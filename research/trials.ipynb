# %%
import gdown

# %%
url="https://drive.google.com/file/d/1LYPIY2fR0vOa9ZSOTf_s5dnf0CIqWFg0/view"

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1LYPIY2fR0vOa9ZSOTf_s5dnf0CIqWFg0
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1LYPIY2fR0vOa9ZSOTf_s5dnf0CIqWFg0&confirm=t&uuid=169b0c45-72dc-4898-b9a7-badd47beb0ef
# To: d:\Kidney-Disease-Classification-Project\research\kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:14<00:00, 4.03MB/s]
# 'kidney-CT-Scan-data.zip'

# %%
file_id=url.split("/")[-2]
file_id
# Out:
# '1LYPIY2fR0vOa9ZSOTf_s5dnf0CIqWFg0'
